# %%
# ==============================================================
#   AUTOMATIZACIÓN COMPLETA PARA MLP_MULTICAPAS.CU (CIFAR-10)
#   Sin fragmentos, en un solo bloque, al estilo profesional
# ==============================================================

import os

print("=============================================")
print(" PASO 1: COMPROBANDO GPU Y ENTORNO CUDA")
print("=============================================")

# Comprobar GPU disponible
# !nvidia-smi
# !nvcc --version


print("\n=============================================")
print(" PASO 2: DESCARGANDO CIFAR-10 (binario)     ")
print("=============================================")

# Descargar dataset CIFAR-10 formato binario
# !wget -q -c https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# !tar -xzf cifar-10-binary.tar.gz

print("✔ CIFAR-10 descargado y extraído correctamente.")


print("\n=============================================")
print(" PASO 3: CLONANDO REPOSITORIO GITHUB        ")
print("=============================================")

# Limpiar clonaciones previas
# !rm -rf Inteligencia_Artificial

# Clonar repo
# !git clone https://github.com/aaabriceno/Inteligencia_Artificial.git

print("✔ Repositorio clonado correctamente.")

print("\nArchivos disponibles en T7MLPImagenes:")
# !ls Inteligencia_Artificial/T7MLPImagenes/


print("\n=============================================")
print(" PASO 4: MOVIENDO CIFAR-10 AL DIRECTORIO CUDA")
print("=============================================")

# Copiar los .bin dentro del folder donde está mlp_multicapas.cu
# !cp cifar-10-batches-bin/*.bin Inteligencia_Artificial/T7MLPImagenes/

# Cambiar directorio a donde está el archivo .cu
# %cd Inteligencia_Artificial/T7MLPImagenes/

print("\n✔ Archivos en el directorio actual:")
# !ls -lh


print("\n=============================================")
print(" PASO 5: COMPILANDO mlp_multicapas.cu        ")
print("=============================================")

# NOTA IMPORTANTE:
# -arch=sm_75 funciona para T4 y GPUs modernas.
# Si Colab te da una K80, debes cambiar a sm_37 manually.
# !nvcc mlp_multicapas.cu -o mlp_multicapas_exe -std=c++17 -O2 -arch=sm_75

print("\n✔ Compilación completada. Archivo generado: mlp_multicapas_exe")


print("\n=============================================")
print(" PASO 6: EJECUTANDO EL PROGRAMA CUDA         ")
print("=============================================")

# !./mlp_multicapas_exe

print("\n=============================================")
print("  EJECUCIÓN FINALIZADA EXITOSAMENTE          ")
print("=============================================")
