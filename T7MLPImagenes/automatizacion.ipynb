# %%
# ==============================================================
#   AUTOMATIZACIÓN MLP_MULTICAPAS.CU - FIX FINAL
# ==============================================================

import os

print("====== RESET PATH ======")
# %cd /content

print("\n=============================================")
print(" PASO 1: GPU y CUDA")
print("=============================================")
# !nvidia-smi
# !nvcc --version


print("\n=============================================")
print(" PASO 2: DESCARGANDO CIFAR-10 (binario)")
print("=============================================")
# !rm -rf cifar-10-batches-bin
# !wget -q -c https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
# !tar -xzf cifar-10-binary.tar.gz
print("✔ CIFAR-10 descargado.")


print("\n=============================================")
print(" PASO 3: CLONANDO REPOSITORIO")
print("=============================================")
# !rm -rf Inteligencia_Artificial
# !git clone https://github.com/aaabriceno/Inteligencia_Artificial.git
print("✔ Repositorio clonado.")


print("\n=============================================")
print(" PASO 4: PREPARANDO DIRECTORIO")
print("=============================================")

# %cd /content/Inteligencia_Artificial/T7MLPImagenes/

#  FIX IMPORTANTE:
# tu código espera "cifar-10-batches-bin/*.bin"
# así que creamos esa carpeta y movemos allí los binarios
# !mkdir -p cifar-10-batches-bin
# !cp /content/cifar-10-batches-bin/*.bin cifar-10-batches-bin/

print("\nArchivos actuales:")
# !ls -lh cifar-10-batches-bin


print("\n=============================================")
print(" PASO 5: COMPILANDO mlp_multicapas.cu")
print("=============================================")

# !nvcc mlp_multicapas.cu -o mlp_multicapas_exe -std=c++17 -O2 -arch=sm_75

print("\n✔ Compilación completa.")


print("\n=============================================")
print(" PASO 6: EJECUTANDO PROGRAMA CUDA")
print("=============================================")

# !./mlp_multicapas_exe

print("\n=============================================")
print(" EJECUCIÓN FINALIZADA")
print("=============================================")
