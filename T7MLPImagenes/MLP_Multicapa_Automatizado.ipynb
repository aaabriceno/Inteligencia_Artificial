# %% [markdown]
# # MLP Multicapa Automatizado

# %%
# !nvidia-smi

# %%
# !git clone https://github.com/aaabriceno/Inteligencia_Artificial.git
# %cd Inteligencia_Artificial/T7MLPImagenes

# %%
import os
if not os.path.exists("cifar_data"):
    os.mkdir("cifar_data")
# %cd cifar_data
if not os.path.exists("cifar-10-batches-bin"):
    # !wget https://www.cs.toronto.edu/~kriz/cifar-10-binary.tar.gz
    # !tar -xvzf cifar-10-binary.tar.gz
# %cd ..

# %%
# !cp cifar_data/cifar-10-batches-bin/*bin .

# %%
# !nvcc mlp_multicapas.cu -o mlp_multicapas -std=c++17 -O2 -lcudart

# %%
# !./mlp_multicapas

# %%
import os
# !ls -lh
if os.path.exists("loss_history.txt"):
    # !head -n 20 loss_history.txt
